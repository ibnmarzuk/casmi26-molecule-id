# %% [markdown]
# # Enveda CASMI 2026 — Kaggle submission notebook
#
# Featured **code** competition. Internet **off**. Write `submission.csv`.
#
# This notebook is a thin wrapper. The scoring cell below `%run`s `../kaggle/casmi26_kaggle_notebook.py`.
# On Kaggle, paste that file into one cell instead.

# %%
from pathlib import Path
src = Path('../kaggle/casmi26_kaggle_notebook.py')
assert src.exists(), src
print('Running', src.resolve())
exec(src.read_text())
